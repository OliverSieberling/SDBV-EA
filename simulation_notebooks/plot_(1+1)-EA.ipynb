# %%
import matplotlib.pyplot as plt
import numpy as np
import math

POEAGen = np.array([204.882, 595.094, 1114.61, 1684.63, 2475.27, 3295.66, 4120.85, 4958.46, 5894.34, 6932.85, 8186.84, 9198.33, 10640.1, 11053.3, 12543.2, 14518.4, 15954.2, 17103.4, 17380.9, 20127.8, 21532.2
])

POEAPessGen = np.array([239.126, 696.09, 1303.14, 2019.69, 2832.87, 3746.94, 4792.48, 5552.29, 6976.03, 7866.96, 9308.07, 10592.9, 11893.2, 13415.3, 14816.1, 16350.9, 18240.2, 19685.3, 20759.4, 23304.7, 24477.8
])

SDBVGen = np.array([182.492, 571.36, 1025, 1654.07, 2231.62, 3008.19, 3607.61, 4714.97, 5545.88, 6595.62, 7503.44, 8474.56, 9763.1, 10772.4, 12626.1, 13386.8, 15030.2, 15535.4, 17184.4, 18410.6, 19635.2])

ADBVGen = np.array([190.488, 574.914, 1020.97, 1635.41, 2259.41, 2992.29, 3769.29, 4751.36, 5405.42, 6628.4, 7462.18, 8514.56, 9602.16, 11336.1, 12061.4, 13234.1, 14602.1, 15275, 17150.6, 18636.5, 19646.8])

FDBVGen = np.array([134.54, 339.76, 592.374, 834.376, 1088.55, 1376.95, 1715.7, 1951.37, 2256.64, 2611.38, 2907.02, 3189.11, 3452.79, 3934.5, 4240.3, 4500.78, 4813.56, 5210.77, 5526.67, 5822.94, 6261.6])

DBVGen = np.array([145.994, 390.374, 677.01, 938.49, 1286.53, 1591.46, 1933.78, 2297.74, 2680.63, 3022.12, 3399.96, 3833.22, 4121.22, 4648.39, 5000.98, 5467.4, 5916.76, 6196.9, 6567.4, 7047.09, 7419.05
])

NLFGen = np.array([136.476, 349.172, 585.97, 838.698, 1150.02, 1413.38, 1710.27, 2018.34, 2369.04, 2660.87, 2991.32, 3327.13, 3649.78, 3993.15, 4394.4, 4710.71, 5073.13, 5372.5, 5786.66, 6078.87, 6483.09])

OMGen = np.array([134.636, 325.53, 578.78, 823.272, 1077.05, 1309.05, 1622.28, 1900, 2233.51, 2582.87, 2771.64, 3118.88, 3480.62, 3707.03, 4145.17, 4296.51, 4744.96, 5042.02, 5483.51, 5732.54, 6074.47])


custom_x_axis = np.array([20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420])

def genUpFunc(n):
    return ((n ** 1.5)*2.5 )
genUp = genUpFunc(custom_x_axis)

def genDownFunc(n):
    return ((n * np.log(n))*2.3 )
genDown = genDownFunc(custom_x_axis)


plt.rcParams['font.size'] = 16

# E[T]
plt.figure(figsize=(9, 6))
plt.plot(SDBVGen, label='Switching DBv',  color='blue', linewidth=2)
plt.plot(POEAGen, label='PO-EA', color = 'darkgrey', linewidth =2)
plt.plot(POEAPessGen, label='PO-EA$^-$', color = 'dimgray', linewidth =2)
plt.plot(ADBVGen, label='Adversarial DBv',  color='purple', linewidth=2)
plt.plot(FDBVGen, label='Friendly DBv',  color='orange', linewidth=2)
plt.plot(DBVGen, label='DBv',  color='green', linewidth=2)
plt.plot(NLFGen, label='Noisy Linear Function',  color='brown', linewidth=2)
plt.plot(OMGen, label= 'OneMax', color = 'red', linewidth = 2)
plt.plot(genUp, label = r'$2.5 \cdot n\sqrt{n}$',linewidth = 2, linestyle= 'dashed')
plt.plot(genDown, label = r'$2.3 \cdot n\log{n}$', color= 'black',linewidth = 2, linestyle= 'dashed')


custom_x_axis_labels = [str(val) if i % 2 == 0 else '' for i, val in enumerate(custom_x_axis)]
plt.xticks(np.arange(len(custom_x_axis)), custom_x_axis_labels)

plt.title(r'$(1+1)$-EA')
plt.xlabel('n')
plt.ylabel(r'E[T]')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
