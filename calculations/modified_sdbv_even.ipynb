# %%
import matplotlib.pyplot as plt
import numpy as np

sdbv = [25.2733, 41.7376, 60.9536, 82.5914, 106.413, 132.238, 159.922, 189.349, 220.422, 253.056, 287.180, 322.731, 359.654, 397.898, 437.42, 478.177, 520.134, 563.257, 607.514, 652.876, 699.317 ]
sdbv_1 = [24.8067, 41.4764, 60.7914, 82.4823, 106.335, 132.179, 159.876, 189.311, 220.390, 253.028, 287.156, 322.710, 359.635, 397.881, 437.404, 478.163, 520.121, 563.245, 607.502, 652.865, 699.307]

plt.rcParams['font.size'] = 22

plt.figure(figsize=(10,6))
plt.plot([x-y for x,y in zip(sdbv_1, sdbv)], label = 'SDBV with cutoff n/2 - 1', linewidth=3, linestyle='dashed', marker = 'o', markersize = '8')
plt.xticks(range(len(custom_x_axis))[0::2], [2*x+6 for x in range(len(custom_x_axis)) if x%2==0])
plt.xlabel('n')
plt.ylabel('Difference to E[T] of SDBV')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('SDBV_even_diff.pdf', format='pdf')
