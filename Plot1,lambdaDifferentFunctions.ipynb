# %%
import matplotlib.pyplot as plt
import numpy as np
import math

#SA F=1.15 s=0.25



SDBVGen = np.array([45.186, 118.566, 196.772, 258.096, 367.266, 432.946, 541.316, 676.474, 843.16, 835.532, 972.02, 1117.08, 1284.39, 1462.44, 1644.57, 1520.07, 1741.4, 1886.12, 1974.22, 2259.92, 2373.45])
SDBVChil =  np.array([271.116, 829.962, 1574.18, 2322.86, 3305.39, 4329.46, 5413.16, 6764.74, 8431.6, 9190.85, 10692.2, 12287.9, 14128.3, 16086.9, 18090.2, 18240.9, 20896.8, 22633.4, 23690.6, 27119.1, 28481.4])

ADBVGen = np.array([44.676, 113.898, 192.414, 263.798, 360.28, 417.042, 563.384, 656.242, 827.21, 827.43, 964.526, 1156.97, 1311.07, 1470, 1727.21, 1544.15, 1746.71, 1909.2, 2130.89, 2273.09, 2360.22])
ADBVChil = np.array([268.056, 797.286, 1539.31, 2374.18, 3242.52, 4170.42, 5633.84, 6562.42, 8272.1, 9101.73, 10609.8, 12726.7, 14421.8, 16170, 18999.4, 18529.8, 20960.5, 22910.4, 25570.6, 27277.1, 28322.7])

FDBVGen = np.array([29.924, 66.318, 94.904, 120.08, 158.146, 170.468, 215.228, 257.08, 293.478, 294.846, 332.064, 373.132, 410.65, 451.854, 501.42, 476.096, 512.232, 557.59, 583.536, 634.78, 652.534])
FDBVChil = np.array([179.544, 464.226, 759.232, 1080.72, 1423.31, 1704.68, 2152.28, 2570.8, 2934.78, 3243.31, 3652.7, 4104.45, 4517.15, 4970.39, 5515.62, 5713.15, 6146.78, 6691.08, 7002.43, 7617.36, 7830.41])

DBVGen = np.array([35.718, 80.412, 118.558, 145.846, 201.282, 230.532, 277.798, 333.814, 388.812, 387.212, 443.686, 493.756, 541.098, 599.318, 658.646, 646.724, 691.552, 745.388, 788, 834.952, 912.866])
DBVChil = np.array([214.308, 562.884, 948.464, 1312.61, 1811.54, 2305.32, 2777.98, 3338.14, 3888.12, 4259.33, 4880.55, 5431.32, 5952.08, 6592.5, 7245.11, 7760.69, 8298.62, 8944.66, 9456, 10019.4, 10954.4])

NLFGen = np.array([30.526, 69.174, 98.004, 125.308, 165.69, 184.546, 225.4, 266.754, 311.486, 310.242, 357.818, 387.196, 435.204, 478.458, 521.094, 500.096, 547.988, 578.386, 629.166, 661.124, 708.66])
NLFChil = np.array([183.156, 484.218, 784.032, 1127.77, 1491.21, 1845.46, 2254, 2667.54, 3114.86, 3412.66, 3936, 4259.16, 4787.24, 5263.04, 5732.03, 6001.15, 6575.86, 6940.63, 7549.99, 7933.49, 8503.92])

OMGen = np.array([28.904, 61.656, 91.04, 113.828, 150.466, 165.848, 204.004, 245.474, 282.2, 288.796, 324.226, 355.674, 392.624, 430.262, 467.734, 451.342, 490.722, 533.734, 567.67, 599.564, 636.164])
OMChil = np.array([173.424, 431.592, 728.32, 1024.45, 1354.19, 1658.48, 2040.04, 2454.74, 2822, 3176.76, 3566.49, 3912.41, 4318.86, 4732.88, 5145.07, 5416.1, 5888.66, 6404.81, 6812.04, 7194.77, 7633.97])



custom_x_axis = np.array([20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420])

def genUpFunc(n):
    return ((n ** 1.5)*1.7/np.log(n) )
genUp = genUpFunc(custom_x_axis)

def genDownFunc(n):
    return ((n)*1.5)
genDown = genDownFunc(custom_x_axis)

def chilUpFunc(n):
    return ((n ** 1.5)*3.4)
chilUp = chilUpFunc(custom_x_axis)

def chilDownFunc(n):
    return (n * np.log(n)*2.9)
chilDown = chilDownFunc(custom_x_axis)




plt.rcParams['font.size'] = 16

# E[T]
plt.figure(figsize=(9, 6))
plt.plot(SDBVGen, label='Switching DBv',  color='blue', linewidth=2)
plt.plot(ADBVGen, label='Adversarial DBv',  color='purple', linewidth=2)
plt.plot(FDBVGen, label='Friendly DBv',  color='orange', linewidth=2)
plt.plot(DBVGen, label='DBv',  color='green', linewidth=2)
plt.plot(NLFGen, label='Noisy Linear Function',  color='brown', linewidth=2)
plt.plot(OMGen, label= 'OneMax', color = 'red', linewidth = 2)
plt.plot(genUp, label = r'$1.7\cdot \frac{n\sqrt{n}}{\log{n}}$',linewidth = 2, linestyle= 'dashed')
plt.plot(genDown, label = r'$1.5\cdot n$', color= 'black',linewidth = 2, linestyle= 'dashed')


custom_x_axis_labels = [str(val) if i % 2 == 0 else '' for i, val in enumerate(custom_x_axis)]
plt.xticks(np.arange(len(custom_x_axis)), custom_x_axis_labels)

plt.title(r'$(1,\lambda)$-EA')
plt.xlabel('n')
plt.ylabel(r'E[T]')
plt.legend()
plt.grid(True)
plt.tight_layout()

# total number of children
plt.figure(figsize=(9, 6))
plt.plot(SDBVChil, label='Switching DBv',  color='blue', linewidth=2)
plt.plot(ADBVChil, label='Adversarial DBv',  color='purple', linewidth=2)
plt.plot(FDBVChil, label='Friendly DBv',  color='orange', linewidth=2)
plt.plot(DBVChil, label='DBv',  color='green', linewidth=2)
plt.plot(NLFChil, label='Noisy Linear Function',  color='brown', linewidth=2)
plt.plot(OMChil, label= 'OneMax', color = 'red', linewidth = 2)
plt.plot(chilUp, label = r'$3.4 \cdot n\sqrt{n}$',linewidth = 2, linestyle= 'dashed')
plt.plot(chilDown, label = r'$2.9 \cdot n\log{n}$', color= 'black',linewidth = 2, linestyle= 'dashed')


custom_x_axis_labels = [str(val) if i % 2 == 0 else '' for i, val in enumerate(custom_x_axis)]
plt.xticks(np.arange(len(custom_x_axis)), custom_x_axis_labels)

plt.title(r'$(1,\lambda)$-EA')
plt.xlabel('n')
plt.ylabel(r'expected function evaluations')
plt.legend()
plt.grid(True)
plt.tight_layout()




plt.show()
