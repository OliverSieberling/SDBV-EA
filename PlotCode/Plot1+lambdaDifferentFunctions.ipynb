# %%
import matplotlib.pyplot as plt
import numpy as np
import math

#SA F=1.15 s=0.25



SDBVGen = np.array([38.916, 98.43, 167.378, 229.722, 322.744, 384.068, 484.432, 581.712, 683.626, 779.028, 873.656, 997.672, 1096.33, 1248.2, 1300.6, 1392.76, 1542.39, 1667.51, 1721.71, 1980.33, 2070.47])
SDBVChil =  np.array([233.496, 689.01, 1339.02, 2067.5, 2904.7, 3840.68, 4844.32, 5817.12, 6836.26, 8569.31, 9610.22, 10974.4, 12059.6, 13730.2, 14306.6, 16713.1, 18508.6, 20010.1, 20660.5, 23764, 24845.7])

ADBVGen = np.array([39.608, 103.732, 165.39, 235.894, 319.088, 384.892, 498.964, 585.956, 723.51, 762.892, 865.188, 1005.61, 1102.92, 1217.66, 1368.89, 1361.77, 1524.01, 1617.8, 1730.44, 1902.04, 2011.97])
ADBVChil = np.array([237.648, 726.124, 1323.12, 2123.05, 2871.79, 3848.92, 4989.64, 5859.56, 7235.1, 8391.81, 9517.07, 11061.7, 12132.1, 13394.3, 15057.8, 16341.3, 18288.1, 19413.6, 20765.2, 22824.4, 24143.6])

FDBVGen = np.array([26.718, 56.556, 85.056, 111.984, 145.782, 163.132, 203.856, 235.252, 268.154, 282.31, 319.228, 346.27, 383.072, 415.55, 450.862, 452.172, 489.08, 517.618, 566.41, 581.446, 610.092])
FDBVChil = np.array([160.308, 395.892, 680.448, 1007.86, 1312.04, 1631.32, 2038.56, 2352.52, 2681.54, 3105.41, 3511.51, 3808.97, 4213.79, 4571.05, 4959.48, 5426.06, 5868.96, 6211.42, 6796.92, 6977.35, 7321.1])

DBVGen = np.array([30.478, 67.876, 106.208, 138.404, 180.418, 214.432, 257.984, 298.814, 342.29, 371.142, 412.554, 465.538, 509.576, 556.374, 599.238, 616.702, 671.478, 695.14, 745.526, 786.432, 842.642])
DBVChil = np.array([182.868, 475.132, 849.664, 1245.64, 1623.76, 2144.32, 2579.84, 2988.14, 3422.9, 4082.56, 4538.09, 5120.92, 5605.34, 6120.11, 6591.62, 7400.42, 8057.74, 8341.68, 8946.31, 9437.18, 10111.7])

NLFGen = np.array([27.454, 58.97, 88.052, 114.736, 148.662, 175.13, 205.592, 246.886, 277.528, 295.924, 338.67, 367.572, 406.04, 442.5, 476.306, 483.636, 505.452, 544.612, 587.304, 614.586, 658.734])
NLFChil = np.array([164.724, 412.79, 704.416, 1032.62, 1337.96, 1751.3, 2055.92, 2468.86, 2775.28, 3255.16, 3725.37, 4043.29, 4466.44, 4867.5, 5239.37, 5803.63, 6065.42, 6535.34, 7047.65, 7375.03, 7904.81])

OMGen = np.array([
25.658, 53.744, 82.018, 104.22, 142.148, 158.152, 190.32, 224.644, 261.04, 269.746, 300.158, 333.068, 365.29, 395.572, 435.786, 438.598, 461.04, 505.758, 533.768, 558.048, 601.064])
OMChil = np.array([153.948, 376.208, 656.144, 937.98, 1279.33, 1581.52, 1903.2, 2246.44, 2610.4, 2967.21, 3301.74, 3663.75, 4018.19, 4351.29, 4793.65, 5263.18, 5532.48, 6069.1, 6405.22, 6696.58, 7212.77])



custom_x_axis = np.array([20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420])

def genUpFunc(n):
    return ((n ** 1.5)*1.5/np.log(n) )
genUp = genUpFunc(custom_x_axis)

def genDownFunc(n):
    return ((n)*1.4)
genDown = genDownFunc(custom_x_axis)

def chilUpFunc(n):
    return ((n ** 1.5)*3)
chilUp = chilUpFunc(custom_x_axis)

def chilDownFunc(n):
    return (n * np.log(n)*2.7)
chilDown = chilDownFunc(custom_x_axis)



plt.rcParams['font.size'] = 16

# E[T]
plt.figure(figsize=(9, 6))
plt.plot(SDBVGen, label='Switching DBv',  color='blue', linewidth=2)
plt.plot(ADBVGen, label='Adversarial DBv',  color='purple', linewidth=2)
plt.plot(FDBVGen, label='Friendly DBv',  color='orange', linewidth=2)
plt.plot(DBVGen, label='DBv',  color='green', linewidth=2)
plt.plot(NLFGen, label='Noisy Linear Function',  color='brown', linewidth=2)
plt.plot(OMGen, label= 'OneMax', color = 'red', linewidth = 2)
plt.plot(genUp, label = r'$1.5\cdot \frac{n\sqrt{n}}{\log{n}}$',linewidth = 2, linestyle= 'dashed')
plt.plot(genDown, label = r'$1.4\cdot n$', color= 'black',linewidth = 2, linestyle= 'dashed')


custom_x_axis_labels = [str(val) if i % 2 == 0 else '' for i, val in enumerate(custom_x_axis)]
plt.xticks(np.arange(len(custom_x_axis)), custom_x_axis_labels)

plt.title(r'$(1+\lambda)$-EA')
plt.xlabel('n')
plt.ylabel(r'E[T]')
plt.legend()
plt.grid(True)
plt.tight_layout()

# total number of children
plt.figure(figsize=(9, 6))
plt.plot(SDBVChil, label='Switching DBv',  color='blue', linewidth=2)
plt.plot(ADBVChil, label='Adversarial DBv',  color='purple', linewidth=2)
plt.plot(FDBVChil, label='Friendly DBv',  color='orange', linewidth=2)
plt.plot(DBVChil, label='DBv',  color='green', linewidth=2)
plt.plot(NLFChil, label='Noisy Linear Function',  color='brown', linewidth=2)
plt.plot(OMChil, label= 'OneMax', color = 'red', linewidth = 2)
plt.plot(chilUp, label = r'$3 \cdot n\sqrt{n}$',linewidth = 2, linestyle= 'dashed')
plt.plot(chilDown, label = r'$2.7 \cdot n\log{n}$', color= 'black',linewidth = 2, linestyle= 'dashed')


custom_x_axis_labels = [str(val) if i % 2 == 0 else '' for i, val in enumerate(custom_x_axis)]
plt.xticks(np.arange(len(custom_x_axis)), custom_x_axis_labels)

plt.title(r'$(1+\lambda)$-EA')
plt.xlabel('n')
plt.ylabel(r'expected function evaluations')
plt.legend()
plt.grid(True)
plt.tight_layout()




plt.show()
